# %%
import ROOT as r
import fedrarootlogon
# Out:
# Welcome to JupyROOT 6.26/10
# Load FEDRA libs

# %%
# !git clone https://github.com/SND-LHC/emu_reco_analysis
# Out:
# fatal: destination path 'emu_reco_analysis' already exists and is not an empty directory.

# %%
import sys
sys.path.insert(1, './emu_reco_analysis/scipy_conversion/') #adding the path to the import
import fedra2scipy_utils as fedra2scipy

# %%
df = fedra2scipy.builddataframe(21,"/eos/user/a/aiulian/sim_fedra/nu_sim_activeemu_withcrisfiles_25_July_2022/")
# Out:
# Reading ScanSet at path  /eos/user/a/aiulian/sim_fedra/nu_sim_activeemu_withcrisfiles_25_July_2022/
# Cut on couples
# Try to open folders at path  /eos/user/a/aiulian/sim_fedra/nu_sim_activeemu_withcrisfiles_25_July_2022//b000021
# loop on 29509 segments over  29509 for plate 60
# loop on 29195 segments over  29195 for plate 59
# loop on 29205 segments over  29205 for plate 58
# loop on 29040 segments over  29040 for plate 57
# loop on 28656 segments over  28656 for plate 56
# loop on 28464 segments over  28464 for plate 55
# loop on 28458 segments over  28458 for plate 54
# loop on 28280 segments over  28280 for plate 53
# loop on 27770 segments over  27770 for plate 52
# loop on 27502 segments over  27502 for plate 51
# loop on 27275 segments over  27275 for plate 50
# loop on 27236 segments over  27236 for plate 49
# loop on 27020 segments over  27020 for plate 48
# loop on 26753 segments over  26753 for plate 47
# loop on 26883 segments over  26883 for plate 46
# ...

# %%
df
# Out:
#                ID  PID             x             y        z        TX  \
# 0            8819    0  352933.34375   9453.689453      0.0 -0.014952
# 1            9036    0  354588.00000  11775.276367      0.0 -0.010835
# 2            9508    0  355476.46875   8445.426758      0.0 -0.006502
# 3           10712    0  369220.12500  15780.021484      0.0  0.875296
# 4           10714    0  367589.37500  15589.591797      0.0  0.253823
# ...           ...  ...           ...           ...      ...       ...
# 1454748  20284431   59  274170.40625  37065.613281 -77585.0 -0.038775
# 1454749  20284454   59  276663.87500  38940.421875 -77585.0  0.038057
# 1454750  20284457   59  276301.06250  38856.460938 -77585.0 -0.064267
# 1454751  20284464   59  275451.90625  40412.343750 -77585.0 -0.004064
# 1454752  20284469   59  275756.12500  38706.789062 -77585.0 -0.001532
#
#                TY  MCEvent  MCTrack  MCMotherID          P  PdgCode
# ...
